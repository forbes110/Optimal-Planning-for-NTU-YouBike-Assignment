# %% [markdown]
# # 2022 Spring OR Final Project
#
# ## Group A
#
# ### Members:
#
# - 吳驊祐 B09705009
# - 周成康 B09705011
# - 陳瑾叡 B09705016
# - 黃戎僔 B09705032
# - 吳天冷 B08303135
# - 李詠如 B07703084
# - 劉德駿 B07801013
# - 李宗霖 B07702044
# - 陳琳瑄 B06B02059
#
# ## File struture:
# ```
# .
# ├── Kmeans_clustered_dist_matrix
# │   ├── Clustered_dist_matrix_labels1.xlsx
# │   ├── Clustered_dist_matrix_labels2.xlsx
# │   ├── Clustered_dist_matrix_labels3.xlsx
# │   ├── Clustered_dist_matrix_labels4.xlsx
# │   ├── Clustered_dist_matrix_labels5.xlsx
# │   ├── Clustered_dist_matrix_labels6.xlsx
# │   ├── Clustered_dist_matrix_labels7.xlsx
# │   ├── Clustered_dist_matrix_labels8.xlsx
# │   └── Clustered_dist_matrix_labels9.xlsx
# ├── TaipeiSansTCBeta-Regular.ttf
# ├── distance_sites.xlsx
# ├── main.py
# ├── readme.ipynb
# ├── spaceInfo_6.1_17.xlsx
# ├── spaceInfo_6.3_10.xlsx
# ├── spaceInfo_6.3_17.xlsx
# ├── spaceInfo_6.3_8.xlsx
# └── youbike_data
#     ├── Step1_getYoubikedata.ipynb
#     └── Step2_Data_Processing_(API).ipynb
# ```
#
# ## Some Infomations:
#
# 1. The k-means and gurobi solver are both in `main.py`
#
# 2. The file `distance_sites` and `spaceIndo_` are necessary.
#
# 3. Check the parameters in `main.py` before you run it.(Line 17-22)
#
#
#
#
# ## Flow chat
#
# 1. `RUN` `/youbikedata/Step1_getYoubikedata.ipynb`
#
# 2. `RUN` `/youbikedata/Step2_Data_Processing_(API).ipynb`
#
# 3. move the `spaceinfo` file to This root folder `./`
#
# 4. `RUN` `main.py`
